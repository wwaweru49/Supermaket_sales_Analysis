# %% [markdown]
# <span style="color: 0.56,0.35,0.01">*\#1.ASK*</span> <span
# style="color: 0.56,0.35,0.01">*\#1.0 Business task*</span> <span
# style="color: 0.56,0.35,0.01">*\#.The average sales amount and the
# number of sales at each branch* </span> <span
# style="color: 0.56,0.35,0.01">*\#.The average unit price for each
# product line*</span> <span style="color: 0.56,0.35,0.01">*\#.Do branches
# make more sale on a specific day of the week*</span> <span
# style="color: 0.56,0.35,0.01">*\#.distribution of average sales amount
# by gender*</span> <span style="color: 0.56,0.35,0.01">*\#.distribution
# of average sales amount by gender per branch*</span> <span
# style="color: 0.56,0.35,0.01">*\#which is the most popular product line
# by quantity sold*</span> <span style="color: 0.56,0.35,0.01">*\#which is
# the most profitable product line*</span> <span
# style="color: 0.56,0.35,0.01">*\#1.1 Stakeholders*</span> <span
# style="color: 0.56,0.35,0.01">*\#stakeholders include the
# following*</span> <span style="color: 0.56,0.35,0.01">*\#.Marketing &
# sales director*</span> <span style="color: 0.56,0.35,0.01">*\#.Analytics
# team*</span> <span style="color: 0.56,0.35,0.01">*\#.Sales team*</span>
# <span style="color: 0.56,0.35,0.01">*\#2.PREPARE*</span> <span
# style="color: 0.56,0.35,0.01">*\#.The data is located on Kaggle &
# contains sales data of different branches over a 3 month period.*</span>
# <span style="color: 0.56,0.35,0.01">*\#.Data is organized in csv
# files*</span> <span style="color: 0.56,0.35,0.01">*\#.Credibility of
# data not in question*</span> <span
# style="color: 0.56,0.35,0.01">*\#.This data has been stripped of all
# identifying information ensuring its privacy*</span> <span
# style="color: 0.56,0.35,0.01">*\#3.PROCESS*</span> <span
# style="color: 0.56,0.35,0.01">*\#.For this project I choose RStudio
# Desktop in order to prepare, process, clean, analyze and create the
# visualizations.*</span> <span style="color: 0.56,0.35,0.01">*\#Data
# review involved the following:*</span> <span
# style="color: 0.56,0.35,0.01">*\#.Checking column names across all the
# 12 original files.*</span> <span
# style="color: 0.56,0.35,0.01">*\#.Checking for missing values.*</span>
# <span style="color: 0.56,0.35,0.01">*\#.Checking of white
# spaces.*</span> <span style="color: 0.56,0.35,0.01">*\#.Checking of
# duplicate records.*</span> <span style="color: 0.56,0.35,0.01">*\#3.1
# COLLECT & DATA WRANGLING*</span> <span
# style="color: 0.56,0.35,0.01">*\#load readr for reading rectangular
# data*</span> <span style="color: 0.56,0.35,0.01">*\#load dplyr for data
# wrangling*</span> <span style="color: 0.56,0.35,0.01">*\#load ggplot2
# for data visualization*</span> <span
# style="color: 0.00,0.00,0.00">library</span>(dplyr)
#
#     ##
#     ## Attaching package: 'dplyr'
#
#     ## The following objects are masked from 'package:stats':
#     ##
#     ##     filter, lag
#
#     ## The following objects are masked from 'package:base':
#     ##
#     ##     intersect, setdiff, setequal, union
#
# <span style="color: 0.00,0.00,0.00">library</span>(readr) <span
# style="color: 0.00,0.00,0.00">library</span>(ggplot2) <span
# style="color: 0.56,0.35,0.01">*\#read data set using the read_csv
# function*</span> supermarket_sales<span
# style="color: 0.56,0.35,0.01">\<-</span><span
# style="color: 0.00,0.00,0.00">read_csv</span>(<span
# style="color: 0.31,0.60,0.02">"C:/Users/user/Desktop/RSTUDIO/supermarket_sales.csv"</span>)
#
#     ## Rows: 1000 Columns: 17
#
#     ## -- Column specification --------------------------------------------------------
#     ## Delimiter: ","
#     ## chr  (8): Invoice_ID, Branch, City, Customer_type, Gender, Product_line, Dat...
#     ## dbl  (8): Unit_price, Quantity, Tax _5%, Total, cogs, gross_margin_percentag...
#     ## time (1): Time
#
#     ##
#     ## i Use `spec()` to retrieve the full column specification for this data.
#     ## i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#
# <span style="color: 0.56,0.35,0.01">*\#3.2 Data Validation*</span> <span
# style="color: 0.00,0.00,0.00">head</span>(supermarket_sales,<span
# style="color: 0.00,0.00,0.81">5</span>)
#
#     ## # A tibble: 5 x 17
#     ##   Invoice_ID  Branch City  Customer_type Gender Product_line Unit_price Quantity
#     ##   <chr>       <chr>  <chr> <chr>         <chr>  <chr>             <dbl>    <dbl>
#     ## 1 750-67-8428 A      Yang~ Member        Female Health and ~       74.7        7
#     ## 2 226-31-3081 C      Nayp~ Normal        Female Electronic ~       15.3        5
#     ## 3 631-41-3108 A      Yang~ Normal        Male   Home and li~       46.3        7
#     ## 4 123-19-1176 A      Yang~ Member        Male   Health and ~       58.2        8
#     ## 5 373-73-7910 A      Yang~ Normal        Male   Sports and ~       86.3        7
#     ## # ... with 9 more variables: Tax _5% <dbl>, Total <dbl>, Date <chr>,
#     ## #   Time <time>, Payment <chr>, cogs <dbl>, gross_margin_percentage <dbl>,
#     ## #   gross_income <dbl>, Rating <dbl>
#
# <span style="color: 0.00,0.00,0.00">tail</span>(supermarket_sales)
#
#     ## # A tibble: 6 x 17
#     ##   Invoice_ID  Branch City  Customer_type Gender Product_line Unit_price Quantity
#     ##   <chr>       <chr>  <chr> <chr>         <chr>  <chr>             <dbl>    <dbl>
#     ## 1 652-49-6720 C      Nayp~ Member        Female Electronic ~       61.0        1
#     ## 2 233-67-5758 C      Nayp~ Normal        Male   Health and ~       40.4        1
#     ## 3 303-96-2227 B      Mand~ Normal        Female Home and li~       97.4       10
#     ## 4 727-02-1313 A      Yang~ Member        Male   Food and be~       31.8        1
#     ## 5 347-56-2442 A      Yang~ Normal        Male   Home and li~       65.8        1
#     ## 6 849-09-3807 A      Yang~ Member        Female Fashion acc~       88.3        7
#     ## # ... with 9 more variables: Tax _5% <dbl>, Total <dbl>, Date <chr>,
#     ## #   Time <time>, Payment <chr>, cogs <dbl>, gross_margin_percentage <dbl>,
#     ## #   gross_income <dbl>, Rating <dbl>
#
# <span style="color: 0.00,0.00,0.00">str</span>(supermarket_sales)
#
#     ## spec_tbl_df [1,000 x 17] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#     ##  $ Invoice_ID             : chr [1:1000] "750-67-8428" "226-31-3081" "631-41-3108" "123-19-1176" ...
#     ##  $ Branch                 : chr [1:1000] "A" "C" "A" "A" ...
#     ##  $ City                   : chr [1:1000] "Yangon" "Naypyitaw" "Yangon" "Yangon" ...
#     ##  $ Customer_type          : chr [1:1000] "Member" "Normal" "Normal" "Member" ...
#     ##  $ Gender                 : chr [1:1000] "Female" "Female" "Male" "Male" ...
#     ##  $ Product_line           : chr [1:1000] "Health and beauty" "Electronic accessories" "Home and lifestyle" "Health and beauty" ...
#     ##  $ Unit_price             : num [1:1000] 74.7 15.3 46.3 58.2 86.3 ...
#     ##  $ Quantity               : num [1:1000] 7 5 7 8 7 7 6 10 2 3 ...
#     ##  $ Tax _5%                : num [1:1000] 26.14 3.82 16.22 23.29 30.21 ...
#     ##  $ Total                  : num [1:1000] 549 80.2 340.5 489 634.4 ...
#     ##  $ Date                   : chr [1:1000] "1/5/2019" "3/8/2019" "3/3/2019" "1/27/2019" ...
#     ##  $ Time                   : 'hms' num [1:1000] 13:08:00 10:29:00 13:23:00 20:33:00 ...
#     ##   ..- attr(*, "units")= chr "secs"
#     ##  $ Payment                : chr [1:1000] "Ewallet" "Cash" "Credit card" "Ewallet" ...
#     ##  $ cogs                   : num [1:1000] 522.8 76.4 324.3 465.8 604.2 ...
#     ##  $ gross_margin_percentage: num [1:1000] 4.76 4.76 4.76 4.76 4.76 ...
#     ##  $ gross_income           : num [1:1000] 26.14 3.82 16.22 23.29 30.21 ...
#     ##  $ Rating                 : num [1:1000] 9.1 9.6 7.4 8.4 5.3 4.1 5.8 8 7.2 5.9 ...
#     ##  - attr(*, "spec")=
#     ##   .. cols(
#     ##   ..   Invoice_ID = col_character(),
#     ##   ..   Branch = col_character(),
#     ##   ..   City = col_character(),
#     ##   ..   Customer_type = col_character(),
#     ##   ..   Gender = col_character(),
#     ##   ..   Product_line = col_character(),
#     ##   ..   Unit_price = col_double(),
#     ##   ..   Quantity = col_double(),
#     ##   ..   `Tax _5%` = col_double(),
#     ##   ..   Total = col_double(),
#     ##   ..   Date = col_character(),
#     ##   ..   Time = col_time(format = ""),
#     ##   ..   Payment = col_character(),
#     ##   ..   cogs = col_double(),
#     ##   ..   gross_margin_percentage = col_double(),
#     ##   ..   gross_income = col_double(),
#     ##   ..   Rating = col_double()
#     ##   .. )
#     ##  - attr(*, "problems")=<externalptr>
#
# <span style="color: 0.00,0.00,0.00">glimpse</span>(supermarket_sales)
#
#     ## Rows: 1,000
#     ## Columns: 17
#     ## $ Invoice_ID              <chr> "750-67-8428", "226-31-3081", "631-41-3108", "~
#     ## $ Branch                  <chr> "A", "C", "A", "A", "A", "C", "A", "C", "A", "~
#     ## $ City                    <chr> "Yangon", "Naypyitaw", "Yangon", "Yangon", "Ya~
#     ## $ Customer_type           <chr> "Member", "Normal", "Normal", "Member", "Norma~
#     ## $ Gender                  <chr> "Female", "Female", "Male", "Male", "Male", "M~
#     ## $ Product_line            <chr> "Health and beauty", "Electronic accessories",~
#     ## $ Unit_price              <dbl> 74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.8~
#     ## $ Quantity                <dbl> 7, 5, 7, 8, 7, 7, 6, 10, 2, 3, 4, 4, 5, 10, 10~
#     ## $ `Tax _5%`               <dbl> 26.1415, 3.8200, 16.2155, 23.2880, 30.2085, 29~
#     ## $ Total                   <dbl> 548.9715, 80.2200, 340.5255, 489.0480, 634.378~
#     ## $ Date                    <chr> "1/5/2019", "3/8/2019", "3/3/2019", "1/27/2019~
#     ## $ Time                    <time> 13:08:00, 10:29:00, 13:23:00, 20:33:00, 10:37~
#     ## $ Payment                 <chr> "Ewallet", "Cash", "Credit card", "Ewallet", "~
#     ## $ cogs                    <dbl> 522.83, 76.40, 324.31, 465.76, 604.17, 597.73,~
#     ## $ gross_margin_percentage <dbl> 4.761905, 4.761905, 4.761905, 4.761905, 4.7619~
#     ## $ gross_income            <dbl> 26.1415, 3.8200, 16.2155, 23.2880, 30.2085, 29~
#     ## $ Rating                  <dbl> 9.1, 9.6, 7.4, 8.4, 5.3, 4.1, 5.8, 8.0, 7.2, 5~
#
# <span style="color: 0.56,0.35,0.01">*\#4Data Cleaning*</span> <span
# style="color: 0.56,0.35,0.01">*\#Check for missing values*</span> <span
# style="color: 0.00,0.00,0.00">colSums</span>(<span
# style="color: 0.00,0.00,0.00">is.na</span>(supermarket_sales))
#
#     ##              Invoice_ID                  Branch                    City
#     ##                       0                       0                       0
#     ##           Customer_type                  Gender            Product_line
#     ##                       0                       0                       0
#     ##              Unit_price                Quantity                 Tax _5%
#     ##                       0                       0                       0
#     ##                   Total                    Date                    Time
#     ##                       0                       0                       0
#     ##                 Payment                    cogs gross_margin_percentage
#     ##                       0                       0                       0
#     ##            gross_income                  Rating
#     ##                       0                       0
#
# <span style="color: 0.56,0.35,0.01">*\#check for duplicates*</span>
# <span style="color: 0.00,0.00,0.00">distinct</span>(supermarket_sales)
#
#     ## # A tibble: 1,000 x 17
#     ##    Invoice_ID Branch City  Customer_type Gender Product_line Unit_price Quantity
#     ##    <chr>      <chr>  <chr> <chr>         <chr>  <chr>             <dbl>    <dbl>
#     ##  1 750-67-84~ A      Yang~ Member        Female Health and ~       74.7        7
#     ##  2 226-31-30~ C      Nayp~ Normal        Female Electronic ~       15.3        5
#     ##  3 631-41-31~ A      Yang~ Normal        Male   Home and li~       46.3        7
#     ##  4 123-19-11~ A      Yang~ Member        Male   Health and ~       58.2        8
#     ##  5 373-73-79~ A      Yang~ Normal        Male   Sports and ~       86.3        7
#     ##  6 699-14-30~ C      Nayp~ Normal        Male   Electronic ~       85.4        7
#     ##  7 355-53-59~ A      Yang~ Member        Female Electronic ~       68.8        6
#     ##  8 315-22-56~ C      Nayp~ Normal        Female Home and li~       73.6       10
#     ##  9 665-32-91~ A      Yang~ Member        Female Health and ~       36.3        2
#     ## 10 692-92-55~ B      Mand~ Member        Female Food and be~       54.8        3
#     ## # ... with 990 more rows, and 9 more variables: Tax _5% <dbl>, Total <dbl>,
#     ## #   Date <chr>, Time <time>, Payment <chr>, cogs <dbl>,
#     ## #   gross_margin_percentage <dbl>, gross_income <dbl>, Rating <dbl>
#
# <span style="color: 0.56,0.35,0.01">*\#5.Analysis*</span> <span
# style="color: 0.56,0.35,0.01">*\#.The average sales amount per
# branch*</span> avg_sales_amnt<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Branch)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_sales=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(Total)) avg_sales_amnt
#
#     ## # A tibble: 3 x 2
#     ##   Branch avg_sales
#     ##   <chr>      <dbl>
#     ## 1 A           312.
#     ## 2 B           320.
#     ## 3 C           337.
#
# <span style="color: 0.56,0.35,0.01">*\#.The average unit price of
# products in each product line*</span> avg_unit_price<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Product_line)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_unit_price=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(Unit_price))<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">arrange</span>(<span
# style="color: 0.00,0.00,0.00">desc</span>(avg_unit_price))
# avg_unit_price
#
#     ## # A tibble: 6 x 2
#     ##   Product_line           avg_unit_price
#     ##   <chr>                           <dbl>
#     ## 1 Fashion accessories              57.2
#     ## 2 Sports and travel                57.0
#     ## 3 Food and beverages               56.0
#     ## 4 Home and lifestyle               55.3
#     ## 5 Health and beauty                54.9
#     ## 6 Electronic accessories           53.6
#
# <span style="color: 0.56,0.35,0.01">*\#.distribution of average sales
# amount by gender*</span> avg_sales_by_gender<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Gender)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_sales=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(Total)) avg_sales_by_gender
#
#     ## # A tibble: 2 x 2
#     ##   Gender avg_sales
#     ##   <chr>      <dbl>
#     ## 1 Female      335.
#     ## 2 Male        311.
#
# <span style="color: 0.56,0.35,0.01">*\#.distribution of average sales
# amount by gender per branch*</span> avg_sales_by_gender_branch<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Gender,Branch)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_sales=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(Total))
#
#     ## `summarise()` has grouped output by 'Gender'. You can override using the `.groups` argument.
#
# avg_sales_by_gender_branch
#
#     ## # A tibble: 6 x 3
#     ## # Groups:   Gender [2]
#     ##   Gender Branch avg_sales
#     ##   <chr>  <chr>      <dbl>
#     ## 1 Female A           331.
#     ## 2 Female B           327.
#     ## 3 Female C           347.
#     ## 4 Male   A           296.
#     ## 5 Male   B           313.
#     ## 6 Male   C           326.
#
# <span style="color: 0.56,0.35,0.01">*\#which is the most popular product
# line by quantity sold*</span> popular_product<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Product_line)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_qnty=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(Quantity))<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">arrange</span>(<span
# style="color: 0.00,0.00,0.00">desc</span>(avg_qnty)) popular_product
#
#     ## # A tibble: 6 x 2
#     ##   Product_line           avg_qnty
#     ##   <chr>                     <dbl>
#     ## 1 Electronic accessories     5.71
#     ## 2 Home and lifestyle         5.69
#     ## 3 Health and beauty          5.62
#     ## 4 Sports and travel          5.54
#     ## 5 Food and beverages         5.47
#     ## 6 Fashion accessories        5.07
#
# <span style="color: 0.56,0.35,0.01">*\#which is the most profitable
# product line*</span> profitable_product<span
# style="color: 0.56,0.35,0.01">\<-</span>supermarket_sales<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">group_by</span>(Product_line)<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">summarise</span>(<span
# style="color: 0.77,0.63,0.00">avg_gross_income=</span><span
# style="color: 0.00,0.00,0.00">mean</span>(gross_income))<span
# style="color: 0.00,0.00,0.00">%\>%</span> <span
# style="color: 0.00,0.00,0.00">arrange</span>(<span
# style="color: 0.00,0.00,0.00">desc</span>(avg_gross_income))
# profitable_product
#
#     ## # A tibble: 6 x 2
#     ##   Product_line           avg_gross_income
#     ##   <chr>                             <dbl>
#     ## 1 Home and lifestyle                 16.0
#     ## 2 Sports and travel                  15.8
#     ## 3 Health and beauty                  15.4
#     ## 4 Food and beverages                 15.4
#     ## 5 Electronic accessories             15.2
#     ## 6 Fashion accessories                14.5
#
# <span style="color: 0.56,0.35,0.01">*\#6.VISUALIZATON*</span> <span
# style="color: 0.56,0.35,0.01">*\#.The average sales amount per
# branch*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(avg_sales_amnt, <span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Branch,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_sales))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()
#
# <span class="image">image</span>
#
# <span style="color: 0.56,0.35,0.01">*\#.The average unit price of
# products in each product line*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(avg_unit_price,<span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Product_line,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_unit_price))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()
#
# <span class="image">image</span>
#
# <span style="color: 0.56,0.35,0.01">*\#.distribution of average sales
# amount by gender*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(avg_sales_by_gender,<span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Gender,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_sales,<span
# style="color: 0.77,0.63,0.00">color=</span>Gender))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()
#
# <span class="image">image</span>
#
# <span style="color: 0.56,0.35,0.01">*\#.distribution of average sales
# amount by gender per branch*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(avg_sales_by_gender_branch,<span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Gender,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_sales))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">facet_wrap</span>(<span
# style="color: 0.00,0.00,0.00">\~</span>Branch)
#
# <span class="image">image</span>
#
# <span style="color: 0.56,0.35,0.01">*\#which is the most popular product
# line by quantity sold*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(popular_product,<span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Product_line,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_qnty))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()
#
# <span class="image">image</span>
#
# <span style="color: 0.56,0.35,0.01">*\#which is the most profitable
# product line*</span> <span
# style="color: 0.00,0.00,0.00">ggplot</span>(profitable_product,<span
# style="color: 0.00,0.00,0.00">aes</span>(<span
# style="color: 0.77,0.63,0.00">x=</span>Product_line,<span
# style="color: 0.77,0.63,0.00">y=</span>avg_gross_income,<span
# style="color: 0.77,0.63,0.00">color=</span>Product_line))<span
# style="color: 0.00,0.00,0.00">+</span> <span
# style="color: 0.00,0.00,0.00">geom_col</span>()
#
# <span class="image">image</span>
